# %%
from ascfd.logistics.inputs import Inputs
from ascfd.simulation import Simulation

# %%
inp = Inputs("problems/riemann.ini")

# %%
s = Simulation(inp)

# %%
s.run()
# Out:
# Timestep: 0, Current time: 0.0
# Timestep: 1, Current time: 0.0001433911981749181
# Timestep: 2, Current time: 0.0002867823963498362
# Timestep: 3, Current time: 0.00043017359452475435
# Timestep: 4, Current time: 0.0005735647926996724
# Timestep: 5, Current time: 0.0007169559908745905
# Timestep: 6, Current time: 0.0008603471890495086
# Timestep: 7, Current time: 0.0010037383872244267
# Timestep: 8, Current time: 0.0011471295853993449
# Timestep: 9, Current time: 0.001290520783574263
# Timestep: 10, Current time: 0.0014339119817491813
# Timestep: 11, Current time: 0.0015773031799240994
# Timestep: 12, Current time: 0.0017206943780990176
# Timestep: 13, Current time: 0.0018640855762739358
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s.run()
#
# File ~/Documents/GitHub/realASCFD/ascfd/simulation.py:54, in Simulation.run(self)
#      51 print("\033" + f"Timestep: {self.timestep}, Current time: {self.t}" + "\033")
#      53 if self.inp.timeStepper == "RK1":
# ---> 54     self.electrons.update()
#      55     self.ions.update()
#      56     self.neutrals.update()
#
# File ~/Documents/GitHub/realASCFD/ascfd/species/fluid.py:82, in FluidSpecies.update(self)
#      80     for j in range(self.inp.numghosts, self.inp.ny + self.inp.numghosts):
#      81         for icomp in range(self.c.NUMQ):
# ---> 82             consU_new[icomp, i, j] = consU[icomp, i, j] - (
#      83                 (self.dt / self.dx) * (right_flux[icomp, i, j] - left_flux[icomp, i, j]) +
#      84                 (self.dt / self.dy) * (top_flux[icomp, i, j] - bottom_flux[icomp, i, j]))
#      86 self.bcs.apply_bcs()
#      88 charge_density = self.get_charge_density()
#
# KeyboardInterrupt:
