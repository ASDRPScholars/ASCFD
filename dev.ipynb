# %%
from ascfd.inputs import Inputs
from ascfd.simulation import Simulation
import numpy as np 
import sys
import faulthandler

np.set_printoptions(threshold=sys.maxsize)

faulthandler.enable()

inp = Inputs("problems/hall_thruster.ini")
s = Simulation(inp)

# %%
s.run()
