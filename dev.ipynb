# %%
from ascfd.inputs import Inputs
from ascfd.simulation import Simulation

# %%
inp = Inputs("problems/hall_thruster.ini")

# %%
s = Simulation(inp)
# Out:
# x range: 0.0 to 1.0
# x_c: 0.6
# sigma: 0.05
# x shape: (100,)
# ic_grid[:,:,1] shape: (100, 40)
# Gaussian 1D max: 0.009934913278422984
# Gaussian 1D at x_c: 0.01
# (100, 40, 3)
# (100,)
# ic_grid max after assignment: 0.009934913278422984
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s = Simulation(inp)
#
# File ~/Documents/GitHub/realASCFD/ascfd/simulation.py:31, in Simulation.__init__(self, a_inputs)
#      29 self.c = FluidConstants(a_inputs)
#      30 self.pc = ParticleConstants()
# ---> 31 self.fields = Fields(self.inp)
#      33 self.inp = self._phys_to_normal(a_inputs)
#      35 # Initialize plasma normalization
#
# File ~/Documents/GitHub/realASCFD/ascfd/fields/fields.py:45, in Fields.__init__(self, a_inputs)
#      41 self.eps0 = 8.854e-12  # TODO: CHECK — Permittivity of free space
#      42 # self.eps0 = 1e-50
#      43
#      44 # Initialize plasma normalization
# ---> 45 self.plasma_refs = PlasmaReferences(
#      46     n0=1e18, T0=1000.0,
#      47     species_mass=9.1e-31, species_charge=1.6e-19
#      48 )
#      50 # Normalized permittivity: ε₀ = 1 in plasma units
#      51 self.eps0_normalized = 1.0
#
# TypeError: PlasmaReferences.__init__() got an unexpected keyword argument 'n0'

# %%
s.run()
