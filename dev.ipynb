# %%
from ascfd.inputs import Inputs
from ascfd.simulation import Simulation

inp = Inputs("problems/hall_thruster.ini")
s = Simulation(inp)
# Out:
# /Users/matthewfang/anaconda3/lib/python3.10/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# CALLED PHYS TO NORMAL
# normal_inp.dx 0.0005
# normal_inp.xlim (0.0, 0.05)
# INITIALIZED ELECTRONS
# [ics] QN STATIC!!
# [ics] INIT WITH: [[1.e+17 1.e+17 1.e+17 ... 1.e+17 1.e+17 1.e+17]
#  [1.e+17 1.e+17 1.e+17 ... 1.e+17 1.e+17 1.e+17]
#  [1.e+17 1.e+17 1.e+17 ... 1.e+17 1.e+17 1.e+17]
#  ...
#  [1.e+17 1.e+17 1.e+17 ... 1.e+17 1.e+17 1.e+17]
#  [1.e+17 1.e+17 1.e+17 ... 1.e+17 1.e+17 1.e+17]
#  [1.e+17 1.e+17 1.e+17 ... 1.e+17 1.e+17 1.e+17]]
# Loaded elastic: 199 data points from 0.000e+00 to 9.651e+02 eV
# Loaded exc1: 201 data points from 8.315e+00 to 9.734e+02 eV
# Loaded exc2: 201 data points from 9.447e+00 to 9.745e+02 eV
# Loaded exc3: 201 data points from 9.917e+00 to 9.750e+02 eV
# Loaded exc4: 201 data points from 1.170e+01 to 9.768e+02 eV
# Loaded ionization: 201 data points from 1.213e+01 to 9.772e+02 eV
# Loaded ion_elastic: 114 data points from 0.000e+00 to 1.000e+04 eV
# Loaded ion_backward: 114 data points from 0.000e+00 to 1.000e+04 eV
# Initialized i with 5 components, capacity 137280
# Initialized 45760 active i particles
# Initialized n with 5 components, capacity 137280
# Initialized 45760 active n particles
# PLOT VARS ARE ['n_e', 'u_e', 'eps_e', 'By', 'n_n', 'n_i', 'n', 'i']
# !EXTENT! [0.0, 0.05, 0.035, 0.05]
# L IS 1
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05

# %%
s.run()
# Out:
# Timestep: 0, Current time: 0.0
# !START! BEGINNING UPDATE: first active particles = [0. 0. 0.]
# !B! BEFORE BOUNDARY CHECK: x_positions = []
# !B! AFTER BOUNDARY CHECK: x_positions = []
# --##-- COLLISION EVENTS FOR n
# ionization 0.0
# excitations 0.0
# elastic 0.0
# !END! END UPDATE: first active particles = NONE
# !START! BEGINNING UPDATE: first active particles = [0. 0. 0.]
# !B! BEFORE BOUNDARY CHECK: x_positions = []
# !B! AFTER BOUNDARY CHECK: x_positions = []
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# initializing random!
# Warning: Skipping particle with wrong component count: got 4000, expected 5
# Warning: Skipping particle with wrong component count: got 4000, expected 5
# Warning: Skipping particle with wrong component count: got 4000, expected 5
# Warning: Skipping particle with wrong component count: got 4000, expected 5
# Warning: Skipping particle with wrong component count: got 4000, expected 5
# a
# --##-- COLLISION EVENTS FOR i
# ionization 0.0
# excitations 0.0
# elastic 0.0
# !END! END UPDATE: first active particles = NONE
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# got all k
# PLOT VARS ARE ['n_e', 'u_e', 'eps_e', 'By', 'n_n', 'n_i', 'n', 'i']
# !EXTENT! [0.0, 0.05, 0.035, 0.05]
# L IS 1
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# X LIM 0.05
# y LIM 0.05
# /Users/matthewfang/Documents/GitHub/realASCFD/ascfd/fluid/quasineutral/species.py:155: LinAlgWarning: Ill-conditioned matrix (rcond=5.79857e-42): result may not be accurate.
#   _energy_e_plus = linalg.solve(a, b, assume_a='tridiagonal')
# X LIM 0.05
# y LIM 0.05
# Timestep: 1, Current time: 1e-10
# !START! BEGINNING UPDATE: first active particles = NONE
# --##-- COLLISION EVENTS FOR n
# ionization 0.0
# excitations 0.0
# elastic 0.0
# !END! END UPDATE: first active particles = NONE
# !START! BEGINNING UPDATE: first active particles = NONE
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 s.run()
#
# File ~/Documents/GitHub/realASCFD/ascfd/simulation.py:312, in Simulation.run(self)
#     310 if self.inp.e_system == "quasineutral":
#     311     self.neutrals.update()
# --> 312     self.ions.update()
#     313     self.electrons.update()
#     315 else:
#
# File ~/Documents/GitHub/realASCFD/ascfd/particle/species.py:260, in ParticleSpecies.update(self)
#     258 n_e = self.simulation.get_species_number_density("e")
#     259 N = self.simulation.get_species_number_density("n")
# --> 260 k_iz = self.simulation.get_coeffs("k_iz")
#     262 n_iz = n_e * N * k_iz
#     264 iz_particles = self.ics.apply_ics(ic="random")
#
# File ~/Documents/GitHub/realASCFD/ascfd/simulation.py:207, in Simulation.get_coeffs(self, column_type, energy_e)
#     204         int_energy_e = round(energy_e[i, j])
#     205         row = df.loc[df['epsilon_eV'] == int_energy_e]
# --> 207         k_grid[i, j] = row[column].iloc[0]
#     209     print("got all k")
#     211 return k_grid
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds
